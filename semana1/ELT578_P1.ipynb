# %% [markdown]
# <center>Universidade Federal de Viçosa</center>
# <center>Coordenadoria de Educação Aberta e a Distância</center>
# <center>Inteligência Artificial e Computacional</center>
# <center>ELT578 - Análise de Imagens e Visão Computacional</center>
# <center>TURMA 2023/1</center>
#
# **<center>AULA PRÁTICA 1: Comandos Básicos para Análise de Imagens </center>**

# %%
#Permissão para acessar o drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Importando bibliotecas
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

#Imagem colorida
img = cv2.imread('/content/drive/MyDrive/ELT578/SEMANA_1/flower.jpeg')

cv2_imshow(img)

print ('Dimensoes da Imagem Flor (linhas, colunas e bandas) = ', img.shape)
print ('Tamanho (px) da Imagem Flor = ', img.size)
print ('Valores das bandas BGR na linha 100 e coluna 100 da Flor = ', img[99,99])
print ('Valor da banda azul na linha 100 e coluna 100 da Flor = ', img[99,99,0])
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
img2 = cv2.imread('/content/drive/MyDrive/ELT578/SEMANA_1/flower.jpeg', cv2.IMREAD_GRAYSCALE)
#cv2_imshow(img2)
print ('Dimensoes da Imagem Flor (linhas, colunas e bandas) = ', img2.shape)
print ('Tamanho (px) da Imagem Flor = ', img2.size)
print ('Valores do px em tons de cinza linha 100 e coluna 100 da Flor = ', img2[99,99])
# Out:
# Dimensoes da Imagem Flor (linhas, colunas e bandas) =  (2048, 946)
# Tamanho (px) da Imagem Flor =  1937408
# Valores do px em tons de cinza linha 100 e coluna 100 da Flor =  196

# %%
#Visualizando imagens grandes
from matplotlib import pyplot as plt

plt.imshow(img)
plt.xticks([]), plt.yticks([]) # esconder os valors de Ox e Oy #esconder o eixo
plt.show()

#O OpenCV lê a imagem no sistema BGR, o Matplotlib trabalha no sistema RGB. Então, temos que converter a imagem no momento de visualizar dentro do Matplolib.

# %%
#Visualizando imagens grandes
from matplotlib import pyplot as plt
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.xticks([]), plt.yticks([])
plt.show()

# %%
#Visualizar as duas imagens ao mesmo tempo
titulos = ['Flor RGB', 'Flor Gray']
imagens = [img, img2]

#0,1 em uma lista
for i in list(range(2)): # i varia de 0 a 1
    plt.subplot (1,2,i+1), plt.imshow(cv2.cvtColor(imagens[i], cv2.COLOR_BGR2RGB))
    plt.title(titulos[i])
    plt.xticks([]), plt.yticks([])
plt.show()

# %%
#Salvando Flor Gray
cv2.imwrite('/content/drive/MyDrive/ELT578/SEMANA_1/flowerGray.jpeg', cv2.cvtColor(img, cv2.COLOR_BGR2GRAY))
# Out:
# True

# %%
img = cv2.imread('/content/drive/MyDrive/ELT578/SEMANA_1/Paralelas.bmp',0)

#Qual é o tamanho de armazenamento teórico da imagem?
#https://web.stanford.edu/class/cs101/bits-bytes.html

# Inicialmente, vamos determinar a profundidade do pixel da imagem
print(img.dtype)
print(img.shape)
#Considerando que a imagem tem 2048 linhas e 946 colunas, temos:
npx=500*500

#Pela profundidade do pixel, temos que são necessários 8 bits para armazenar esse valor ou 1 byte,
#logo o número de bytes na imagem coincide com número de pixels, se a imagem possui apenas 1 banda (imagem em escala de cinza).
#Sabendo que 1kB = 1024 bytes, temos:


#Considerando que cada byte de armazenamento é equivalente a 8 bits e que a imagem "Flor" possuí 3 bandas, ou seja, 24bits.
#O tamanho de armazenamento digital em kilobytes (1024bytes) da imagem é dado por:
size=npx/(1024)
print('O tamanho teórico da imagem é %1.3f kB' %size)

import os
print('O tamanho real da imagem é de %1.3f kB' % (os.path.getsize('/content/drive/MyDrive/ELT578/SEMANA_1/Paralelas.bmp')/1024))

#A diferenca se explica porque arquivos bitmap possuem estruturas de tamanho fixo, cabecalho, que armazenam informacoes adicionais como formato do pixel, estruturas de alinhamento e outras informacoes
# Out:
# uint8
# (500, 500)
# O tamanho teórico da imagem é 244.141 kB
# O tamanho real da imagem é de 245.193 kB

# %%
from matplotlib import pyplot as plt
img = cv2.imread('/content/drive/MyDrive/ELT578/SEMANA_1/Fuji.bmp')


#Qual é o tamanho de armazenamento teórico da imagem?

# Inicialmente, vamos determinar a profundidade do pixel da imagem
print(img.dtype)
print(img.shape)
#Considerando que a imagem tem 2048 linhas e 946 colunas, temos:
npx=436*308

#Pela profundidade do pixel, temos que são necessários 8 bits para armazenar esse valor ou 1 byte,
#logo o número de bytes na imagem coincide com número de pixels, se a imagem possui apenas 1 banda (imagem em escala de cinza).
#Sabendo que 1kB = 1024 bytes, temos:


#Considerando que cada byte de armazenamento é equivalente a 8 bits e que a imagem "Flor" possuí 3 bandas, ou seja, 24bits.
#O tamanho de armazenamento digital em kilobytes (1024bytes) da imagem é dado por:
size=npx*3/(1024)
print('O tamanho teórico da imagem é %1.3f kB' %size)

import os
print('O tamanho real da imagem é de %1.3f kB' % (os.path.getsize('/content/drive/MyDrive/ELT578/SEMANA_1/Fuji.bmp')/1024))

#O Truecolor de 24 bits utiliza 8 bits para representar cada uma das cores RGB. 2 elevado a 8 = 256 níveis que combinados geram 16 777 216 cores (256 × 256 × 256).
# Out:
# uint8
# (436, 308, 3)
# O tamanho teórico da imagem é 393.422 kB
# O tamanho real da imagem é de 393.475 kB

# %%
#Salvando a imagem em formato JPEG com 3 diferentes níveis de qualidade
cv2.imwrite('/content/drive/MyDrive/ELT578/SEMANA_1/fuji25.jpeg', img, [int(cv2.IMWRITE_JPEG_QUALITY), 5])
cv2.imwrite('/content/drive/MyDrive/ELT578/SEMANA_1/fuji50.jpeg', img, [int(cv2.IMWRITE_JPEG_QUALITY), 50])
cv2.imwrite('/content/drive/MyDrive/ELT578/SEMANA_1/fuji75.jpeg', img, [int(cv2.IMWRITE_JPEG_QUALITY), 75])
cv2.imwrite('/content/drive/MyDrive/ELT578/SEMANA_1/fuji100.jpeg', img, [int(cv2.IMWRITE_JPEG_QUALITY), 100])


#Visualizar as 4 imagens ao mesmo tempo
img25 = cv2.imread('/content/drive/MyDrive/ELT578/SEMANA_1/fuji25.jpeg')
img50 = cv2.imread('/content/drive/MyDrive/ELT578/SEMANA_1/fuji50.jpeg')
img75 = cv2.imread('/content/drive/MyDrive/ELT578/SEMANA_1/fuji75.jpeg')
img100 = cv2.imread('/content/drive/MyDrive/ELT578/SEMANA_1/fuji100.jpeg')

title = ['Fuji 25', 'Fuji 50', 'Fuji 75', 'Fuji 100']
imagens = [img25, img50, img75, img100]

for i in list(range(4)):
    plt.subplot (2,2,i+1), plt.imshow(cv2.cvtColor(imagens[i], cv2.COLOR_BGR2RGB))
    plt.title(title[i])
    plt.xticks([]), plt.yticks([])
plt.show()

print(img25.shape)
print(img50.shape)
print(img75.shape)
print(img100.shape)

#As imagens foram salvas em quatro padrões de qualidade diferentes (25%, 50%, 75% e 100%), podemos observar que todas as imagens possuem a mesma resolução da imagem, bem como a mesma resolução de brilho (24 bits, dado que uma imagem RGB possuí 3 bandas).
#A mudança quantitativa é então observada a nível de tamanho de armazenamento (kBytes).
#Os formatos de imagem são padrões de codificação, compressão e definição que determinam o tipo de arquivo gráfico, como JPEG, PNG, BMP, GIF e TIFF.
#Muitas vezes, o formato escolhido é uma questão de equilíbrio entre a qualidade e o tamanho da imagem, de acordo com a aplicação desejada.
# Out:
# (436, 308, 3)
# (436, 308, 3)
# (436, 308, 3)
# (436, 308, 3)
